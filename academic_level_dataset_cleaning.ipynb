# %%
import pandas as pd
import glob

# %%
# get data file names
path =r'./data/academic_level/'
filenames = glob.glob(path + "/*.csv")
print(filenames)
# Out:
# ['./data/academic_level/2018_padro_nivell_academic_per_sexe.csv', './data/academic_level/2015_padro_nivell_academic_per_sexe.csv', './data/academic_level/2020_padro_nivell_academic_per_sexe.csv', './data/academic_level/2017_padro_nivell_academic_per_sexe.csv', './data/academic_level/2019_padro_nivell_academic_per_sexe.csv', './data/academic_level/2016_padro_nivell_academic_per_sexe.csv']

# %%
# read all the *.csv inside academic_level/
all_rent_dfs = []
for file in filenames:
    df_per_year = pd.read_csv(file)
    all_rent_dfs.append(df_per_year)
    print(f'Size of {file}: {df_per_year.shape}')
    print(f'Columns of {file}: {df_per_year.columns.to_list()}')
# Out:
# Size of ./data/academic_level/2018_padro_nivell_academic_per_sexe.csv: (876, 8)
# Columns of ./data/academic_level/2018_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell_academic', 'Nombre']
# Size of ./data/academic_level/2015_padro_nivell_academic_per_sexe.csv: (888, 8)
# Columns of ./data/academic_level/2015_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell_academic', 'Nombre']
# Size of ./data/academic_level/2020_padro_nivell_academic_per_sexe.csv: (876, 8)
# Columns of ./data/academic_level/2020_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell_academic', 'Nombre']
# Size of ./data/academic_level/2017_padro_nivell_academic_per_sexe.csv: (876, 8)
# Columns of ./data/academic_level/2017_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell_academic', 'Nombre']
# Size of ./data/academic_level/2019_padro_nivell_academic_per_sexe.csv: (876, 8)
# Columns of ./data/academic_level/2019_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell_academic', 'Nombre']
# Size of ./data/academic_level/2016_padro_nivell_academic_per_sexe.csv: (876, 8)
# Columns of ./data/academic_level/2016_padro_nivell_academic_per_sexe.csv: ['Any', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri', 'Nom_Barri', 'Sexe', 'Nivell acadèmic', 'Nombre']

# %%
# one of the datasets have a different column name (Nivell acadèmic instead of Nivell_academic)
all_rent_dfs[len(all_rent_dfs) - 1] = all_rent_dfs[len(all_rent_dfs) - 1].rename({'Nivell acadèmic':'Nivell_academic'}, axis=1)
all_rent_dfs[len(all_rent_dfs) - 1]
# Out:
#       Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2016               1  Ciutat Vella           1
# 1    2016               1  Ciutat Vella           2
# 2    2016               1  Ciutat Vella           3
# 3    2016               1  Ciutat Vella           4
# 4    2016               2      Eixample           5
# ..    ...             ...           ...         ...
# 871  2016              10    Sant Martí          69
# 872  2016              10    Sant Martí          70
# 873  2016              10    Sant Martí          71
# 874  2016              10    Sant Martí          72
# 875  2016              10    Sant Martí          73
#
#                                         Nom_Barri  Sexe Nivell_academic  \
# 0                                        el Raval  Home   Sense estudis
# 1                                  el Barri Gòtic  Home   Sense estudis
# 2                                  la Barceloneta  Home   Sense estudis
# 3           Sant Pere, Santa Caterina i la Ribera  Home   Sense estudis
# 4                                   el Fort Pienc  Home   Sense estudis
# ..                                            ...   ...             ...
# 871  Diagonal Mar i el Front Marítim del Poblenou  Dona       No consta
# 872                         el Besòs i el Maresme  Dona       No consta
# 873                       Provençals del Poblenou  Dona       No consta
# 874                      Sant Martí de Provençals  Dona       No consta
# 875                           la Verneda i la Pau  Dona       No consta
#
#      Nombre
# 0       301
# 1       100
# 2       181
# 3       120
# 4       140
# ..      ...
# 871      71
# 872     170
# 873     119
# 874     147
# 875     188
#
# [876 rows x 8 columns]

# %%
# make a super-dataframe with all the years
academic_level_df = pd.concat(all_rent_dfs, axis=0, ignore_index=True)
print(academic_level_df.shape)
academic_level_df.head()
# Out:
# (5268, 8)
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2018               1  Ciutat Vella           1
# 1  2018               1  Ciutat Vella           2
# 2  2018               1  Ciutat Vella           3
# 3  2018               1  Ciutat Vella           4
# 4  2018               2      Eixample           5
#
#                                Nom_Barri  Sexe Nivell_academic  Nombre
# 0                               el Raval  Home   Sense estudis     235
# 1                         el Barri Gòtic  Home   Sense estudis      84
# 2                         la Barceloneta  Home   Sense estudis     132
# 3  Sant Pere, Santa Caterina i la Ribera  Home   Sense estudis      93
# 4                          el Fort Pienc  Home   Sense estudis     108

# %%
# translate the columns
academic_level_df = academic_level_df.rename(columns={'Any':'year',
                   'Codi_Districte':'district_code', 
                   'Nom_Districte':'district_name', 
                   'Codi_Barri':'neighborhood_code', 
                   'Nom_Barri':'neighborhood_name', 
                   'Sexe':'sex',
                   'Nivell_academic':'academic_level',
                   'Nombre':'number' })
academic_level_df.head()
# Out:
#    year  district_code district_name  neighborhood_code  \
# 0  2018              1  Ciutat Vella                  1
# 1  2018              1  Ciutat Vella                  2
# 2  2018              1  Ciutat Vella                  3
# 3  2018              1  Ciutat Vella                  4
# 4  2018              2      Eixample                  5
#
#                        neighborhood_name   sex academic_level  number
# 0                               el Raval  Home  Sense estudis     235
# 1                         el Barri Gòtic  Home  Sense estudis      84
# 2                         la Barceloneta  Home  Sense estudis     132
# 3  Sant Pere, Santa Caterina i la Ribera  Home  Sense estudis      93
# 4                          el Fort Pienc  Home  Sense estudis     108

# %%
# translate the sex and academic_level categories
print(f"Unique values for sex: {academic_level_df['sex'].unique().tolist()}")
print(f"Unique values for academic level: {academic_level_df['academic_level'].unique().tolist()}")
# Out:
# Unique values for sex: ['Home', 'Dona']
# Unique values for academic level: ['Sense estudis', "Estudis primaris / certificat d'escolaritat / EGB", 'Batxillerat elemental / graduat escolar / ESO / FPI', 'Batxillerat superior / BUP / COU / FPII / CFGM grau mitjà', 'Estudis universitaris / CFGS grau superior', 'No consta']

# %%
academic_level_df = academic_level_df.assign(sex=lambda df: df['sex'].map({'Home':'man', 'Dona':'woman'}))
academic_level_df['sex'].unique()
# Out:
# array(['man', 'woman'], dtype=object)

# %%
academic_level_df = academic_level_df.assign(academic_level= lambda df: df['academic_level'].map({"Sense estudis":"without education",
                                                                                                  "Estudis primaris / certificat d'escolaritat / EGB":"elementary_school",
                                                                                                  "Batxillerat elemental / graduat escolar / ESO / FPI":"junior_high_school",
                                                                                                  "Batxillerat superior / BUP / COU / FPII / CFGM grau mitjà":"senior_high_school",
                                                                                                  "Estudis universitaris / CFGS grau superior":"bachelors_degree",
                                                                                                  "No consta":"unknown"}))
academic_level_df['academic_level'].unique()
# Out:
# array(['without education', 'elementary_school', 'junior_high_school',
#        'senior_high_school', 'bachelors_degree', 'unknown'], dtype=object)

# %%
# check for NaNs
academic_level_df.isna().sum()
# Out:
# year                 0
# district_code        0
# district_name        0
# neighborhood_code    0
# neighborhood_name    0
# sex                  0
# academic_level       0
# number               0
# dtype: int64

# %%
# set the table to have one row for year and neighborhood
academic_level_df = pd.pivot_table(academic_level_df, values='number', columns=['sex', 'academic_level'], index=['year', 'district_code', 'district_name', 'neighborhood_code', 'neighborhood_name'])
academic_level_df.head()
# Out:
# sex                                                                                                   man  \
# academic_level                                                                           bachelors_degree
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                          4455
#                                  2                 el Barri Gòtic                                    2534
#                                  3                 la Barceloneta                                    1560
#                                  4                 Sant Pere, Santa Caterina i la Ribera             3480
#      2             Eixample      5                 el Fort Pienc                                     4637
#
# sex                                                                                                         \
# academic_level                                                                           elementary_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                           9031
#                                  2                 el Barri Gòtic                                     1567
#                                  3                 la Barceloneta                                     1782
#                                  4                 Sant Pere, Santa Caterina i la Ribera              2225
#      2             Eixample      5                 el Fort Pienc                                      1767
#
# sex                                                                                                          \
# academic_level                                                                           junior_high_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            4966
#                                  2                 el Barri Gòtic                                      1323
#                                  3                 la Barceloneta                                      1726
#                                  4                 Sant Pere, Santa Caterina i la Ribera               1807
#      2             Eixample      5                 el Fort Pienc                                       2341
#
# sex                                                                                                          \
# academic_level                                                                           senior_high_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            3909
#                                  2                 el Barri Gòtic                                      1713
#                                  3                 la Barceloneta                                      1438
#                                  4                 Sant Pere, Santa Caterina i la Ribera               2263
#      2             Eixample      5                 el Fort Pienc                                       3808
#
# sex                                                                                               \
# academic_level                                                                           unknown
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                    5
#                                  2                 el Barri Gòtic                              0
#                                  3                 la Barceloneta                              2
#                                  4                 Sant Pere, Santa Caterina i la Ribera       2
#      2             Eixample      5                 el Fort Pienc                               2
#
# sex                                                                                                         \
# academic_level                                                                           without education
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            443
#                                  2                 el Barri Gòtic                                      124
#                                  3                 la Barceloneta                                      244
#                                  4                 Sant Pere, Santa Caterina i la Ribera               190
#      2             Eixample      5                 el Fort Pienc                                       290
#
# sex                                                                                                 woman  \
# academic_level                                                                           bachelors_degree
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                          4563
#                                  2                 el Barri Gòtic                                    2721
#                                  3                 la Barceloneta                                    1839
#                                  4                 Sant Pere, Santa Caterina i la Ribera             4002
#      2             Eixample      5                 el Fort Pienc                                     5462
#
# sex                                                                                                         \
# academic_level                                                                           elementary_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                           5932
#                                  2                 el Barri Gòtic                                     1170
#                                  3                 la Barceloneta                                     1786
#                                  4                 Sant Pere, Santa Caterina i la Ribera              2020
#      2             Eixample      5                 el Fort Pienc                                      2490
#
# sex                                                                                                          \
# academic_level                                                                           junior_high_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            3732
#                                  2                 el Barri Gòtic                                       977
#                                  3                 la Barceloneta                                      1444
#                                  4                 Sant Pere, Santa Caterina i la Ribera               1464
#      2             Eixample      5                 el Fort Pienc                                       2690
#
# sex                                                                                                          \
# academic_level                                                                           senior_high_school
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            3300
#                                  2                 el Barri Gòtic                                      1515
#                                  3                 la Barceloneta                                      1259
#                                  4                 Sant Pere, Santa Caterina i la Ribera               2067
#      2             Eixample      5                 el Fort Pienc                                       3655
#
# sex                                                                                               \
# academic_level                                                                           unknown
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                    7
#                                  2                 el Barri Gòtic                              1
#                                  3                 la Barceloneta                              1
#                                  4                 Sant Pere, Santa Caterina i la Ribera       5
#      2             Eixample      5                 el Fort Pienc                               3
#
# sex
# academic_level                                                                           without education
# year district_code district_name neighborhood_code neighborhood_name
# 2015 1             Ciutat Vella  1                 el Raval                                            880
#                                  2                 el Barri Gòtic                                      268
#                                  3                 la Barceloneta                                      553
#                                  4                 Sant Pere, Santa Caterina i la Ribera               470
#      2             Eixample      5                 el Fort Pienc                                       571

# %%
# reset the multi-index
academic_level_df = academic_level_df.reset_index()
academic_level_df.head()
# Out:
# sex             year district_code district_name neighborhood_code  \
# academic_level
# 0               2015             1  Ciutat Vella                 1
# 1               2015             1  Ciutat Vella                 2
# 2               2015             1  Ciutat Vella                 3
# 3               2015             1  Ciutat Vella                 4
# 4               2015             2      Eixample                 5
#
# sex                                 neighborhood_name              man  \
# academic_level                                        bachelors_degree
# 0                                            el Raval             4455
# 1                                      el Barri Gòtic             2534
# 2                                      la Barceloneta             1560
# 3               Sant Pere, Santa Caterina i la Ribera             3480
# 4                                       el Fort Pienc             4637
#
# sex                                                                     \
# academic_level elementary_school junior_high_school senior_high_school
# 0                           9031               4966               3909
# 1                           1567               1323               1713
# 2                           1782               1726               1438
# 3                           2225               1807               2263
# 4                           1767               2341               3808
#
# sex                                                 woman                    \
# academic_level unknown without education bachelors_degree elementary_school
# 0                    5               443             4563              5932
# 1                    0               124             2721              1170
# 2                    2               244             1839              1786
# 3                    2               190             4002              2020
# 4                    2               290             5462              2490
#
# sex
# academic_level junior_high_school senior_high_school unknown without education
# 0                            3732               3300       7               880
# 1                             977               1515       1               268
# 2                            1444               1259       1               553
# 3                            1464               2067       5               470
# 4                            2690               3655       3               571

# %%
# reset the multi-columns

new_columns= []

for level1, level2 in academic_level_df.columns:
    if level2:
        new_columns.append(level1 + "_" + level2)
    else:
        new_columns.append(level1)
new_columns
# Out:
# ['year',
#  'district_code',
#  'district_name',
#  'neighborhood_code',
#  'neighborhood_name',
#  'man_bachelors_degree',
#  'man_elementary_school',
#  'man_junior_high_school',
#  'man_senior_high_school',
#  'man_unknown',
#  'man_without education',
#  'woman_bachelors_degree',
#  'woman_elementary_school',
#  'woman_junior_high_school',
#  'woman_senior_high_school',
#  'woman_unknown',
#  'woman_without education']

# %%
academic_level_df = academic_level_df.droplevel(level=0, axis=1)
academic_level_df.head()
# Out:
# academic_level                            \
# 0               2015  1  Ciutat Vella  1
# 1               2015  1  Ciutat Vella  2
# 2               2015  1  Ciutat Vella  3
# 3               2015  1  Ciutat Vella  4
# 4               2015  2      Eixample  5
#
# academic_level                                         bachelors_degree  \
# 0                                            el Raval              4455
# 1                                      el Barri Gòtic              2534
# 2                                      la Barceloneta              1560
# 3               Sant Pere, Santa Caterina i la Ribera              3480
# 4                                       el Fort Pienc              4637
#
# academic_level  elementary_school  junior_high_school  senior_high_school  \
# 0                            9031                4966                3909
# 1                            1567                1323                1713
# 2                            1782                1726                1438
# 3                            2225                1807                2263
# 4                            1767                2341                3808
#
# academic_level  unknown  without education  bachelors_degree  \
# 0                     5                443              4563
# 1                     0                124              2721
# 2                     2                244              1839
# 3                     2                190              4002
# 4                     2                290              5462
#
# academic_level  elementary_school  junior_high_school  senior_high_school  \
# 0                            5932                3732                3300
# 1                            1170                 977                1515
# 2                            1786                1444                1259
# 3                            2020                1464                2067
# 4                            2490                2690                3655
#
# academic_level  unknown  without education
# 0                     7                880
# 1                     1                268
# 2                     1                553
# 3                     5                470
# 4                     3                571

# %%
academic_level_df.columns = new_columns
academic_level_df.head()
# Out:
#    year  district_code district_name  neighborhood_code  \
# 0  2015              1  Ciutat Vella                  1
# 1  2015              1  Ciutat Vella                  2
# 2  2015              1  Ciutat Vella                  3
# 3  2015              1  Ciutat Vella                  4
# 4  2015              2      Eixample                  5
#
#                        neighborhood_name  man_bachelors_degree  \
# 0                               el Raval                  4455
# 1                         el Barri Gòtic                  2534
# 2                         la Barceloneta                  1560
# 3  Sant Pere, Santa Caterina i la Ribera                  3480
# 4                          el Fort Pienc                  4637
#
#    man_elementary_school  man_junior_high_school  man_senior_high_school  \
# 0                   9031                    4966                    3909
# 1                   1567                    1323                    1713
# 2                   1782                    1726                    1438
# 3                   2225                    1807                    2263
# 4                   1767                    2341                    3808
#
#    man_unknown  man_without education  woman_bachelors_degree  \
# 0            5                    443                    4563
# 1            0                    124                    2721
# 2            2                    244                    1839
# 3            2                    190                    4002
# 4            2                    290                    5462
#
#    woman_elementary_school  woman_junior_high_school  \
# 0                     5932                      3732
# 1                     1170                       977
# 2                     1786                      1444
# 3                     2020                      1464
# 4                     2490                      2690
#
#    woman_senior_high_school  woman_unknown  woman_without education
# 0                      3300              7                      880
# 1                      1515              1                      268
# 2                      1259              1                      553
# 3                      2067              5                      470
# 4                      3655              3                      571

# %%
academic_level_df.to_csv('./data/cleaned/academic_level.csv', index=False)
