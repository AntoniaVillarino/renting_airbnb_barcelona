# %%
import pandas as pd
import glob

# %%
# get data file names
path =r'./data/rent_prices'
filenames = glob.glob(path + "/*.csv")
print(filenames)
# Out:
# ['./data/rent_prices/2017_lloguer_preu_trim.csv', './data/rent_prices/2014_lloguer_preu_trim.csv', './data/rent_prices/2019_lloguer_preu_trim.csv', './data/rent_prices/2016_lloguer_preu_trim.csv', './data/rent_prices/2020_lloguer_preu_trim.csv', './data/rent_prices/2015_lloguer_preu_trim.csv', './data/rent_prices/2018_lloguer_preu_trim.csv']

# %%
# read all the *.csv inside rent_prices/
all_rent_dfs = []
for file in filenames:
    df_per_year = pd.read_csv(file)
    all_rent_dfs.append(df_per_year)
    print(f'Size of {file}: {df_per_year.shape}')
# Out:
# Size of ./data/rent_prices/2017_lloguer_preu_trim.csv: (584, 8)
# Size of ./data/rent_prices/2014_lloguer_preu_trim.csv: (584, 8)
# Size of ./data/rent_prices/2019_lloguer_preu_trim.csv: (584, 8)
# Size of ./data/rent_prices/2016_lloguer_preu_trim.csv: (584, 8)
# Size of ./data/rent_prices/2020_lloguer_preu_trim.csv: (292, 8)
# Size of ./data/rent_prices/2015_lloguer_preu_trim.csv: (584, 8)
# Size of ./data/rent_prices/2018_lloguer_preu_trim.csv: (584, 8)

# %%
# make a super-dataframe with all the years
rent_df = pd.concat(all_rent_dfs, axis=0, ignore_index=True)
print(rent_df.shape)
rent_df.head()
# Out:
# (3796, 8)
#     Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2017          1               1  Ciutat Vella           1
# 1  2017          1               1  Ciutat Vella           2
# 2  2017          1               1  Ciutat Vella           3
# 3  2017          1               1  Ciutat Vella           4
# 4  2017          1               2      Eixample           5
#
#                                Nom_Barri                      Lloguer_mitja  \
# 0                               el Raval  Lloguer mitjà mensual (Euros/mes)
# 1                         el Barri Gòtic  Lloguer mitjà mensual (Euros/mes)
# 2                         la Barceloneta  Lloguer mitjà mensual (Euros/mes)
# 3  Sant Pere, Santa Caterina i la Ribera  Lloguer mitjà mensual (Euros/mes)
# 4                          el Fort Pienc  Lloguer mitjà mensual (Euros/mes)
#
#      Preu
# 0  734.99
# 1  905.26
# 2  722.78
# 3  895.28
# 4  871.08

# %%
# rename the columns
rent_df = rent_df.rename(columns={'Any':'year',
                   'Trimestre':'quarter', 
                   'Codi_Districte':'district_code', 
                   'Nom_Districte':'district_name', 
                   'Codi_Barri':'neighborhood_code', 
                   'Nom_Barri':'neighborhood_name', 
                   'Lloguer_mitja':'type_mean_rent', 
                   'Preu':'price'})
rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name                     type_mean_rent  \
# 0                               el Raval  Lloguer mitjà mensual (Euros/mes)
# 1                         el Barri Gòtic  Lloguer mitjà mensual (Euros/mes)
# 2                         la Barceloneta  Lloguer mitjà mensual (Euros/mes)
# 3  Sant Pere, Santa Caterina i la Ribera  Lloguer mitjà mensual (Euros/mes)
# 4                          el Fort Pienc  Lloguer mitjà mensual (Euros/mes)
#
#     price
# 0  734.99
# 1  905.26
# 2  722.78
# 3  895.28
# 4  871.08

# %%
rent_df = rent_df.assign(type_mean_rent= lambda df: 
                         df['type_mean_rent'].map({'Lloguer mitjà mensual (Euros/mes)':'Euros/month','Lloguer mitjà per superfície (Euros/m2 mes)':'Euros/m2 month'}))
rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name type_mean_rent   price
# 0                               el Raval    Euros/month  734.99
# 1                         el Barri Gòtic    Euros/month  905.26
# 2                         la Barceloneta    Euros/month  722.78
# 3  Sant Pere, Santa Caterina i la Ribera    Euros/month  895.28
# 4                          el Fort Pienc    Euros/month  871.08

# %%
def make_period(row):
    return f"{row['year']}Q{row['quarter']}"

# %%
rent_df['period'] = rent_df.apply(make_period, axis=1)
rent_df['period'] = pd.to_datetime(rent_df['period'])
rent_df['period']
# Out:
# 0      2017-01-01
# 1      2017-01-01
# 2      2017-01-01
# 3      2017-01-01
# 4      2017-01-01
#           ...
# 3791   2018-10-01
# 3792   2018-10-01
# 3793   2018-10-01
# 3794   2018-10-01
# 3795   2018-10-01
# Name: period, Length: 3796, dtype: datetime64[ns]

# %%
groupby_object = rent_df.groupby(by='type_mean_rent')
cleaned_rent_df = groupby_object.get_group('Euros/month')
print(cleaned_rent_df.shape)
cleaned_rent_df.head()
# Out:
# (1898, 9)
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name type_mean_rent   price     period
# 0                               el Raval    Euros/month  734.99 2017-01-01
# 1                         el Barri Gòtic    Euros/month  905.26 2017-01-01
# 2                         la Barceloneta    Euros/month  722.78 2017-01-01
# 3  Sant Pere, Santa Caterina i la Ribera    Euros/month  895.28 2017-01-01
# 4                          el Fort Pienc    Euros/month  871.08 2017-01-01

# %%
cleaned_rent_df = cleaned_rent_df.rename(columns={'price':'price_month(€)'})
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name type_mean_rent  price_month(€)  \
# 0                               el Raval    Euros/month          734.99
# 1                         el Barri Gòtic    Euros/month          905.26
# 2                         la Barceloneta    Euros/month          722.78
# 3  Sant Pere, Santa Caterina i la Ribera    Euros/month          895.28
# 4                          el Fort Pienc    Euros/month          871.08
#
#       period
# 0 2017-01-01
# 1 2017-01-01
# 2 2017-01-01
# 3 2017-01-01
# 4 2017-01-01

# %%
cleaned_rent_df.drop('type_mean_rent', axis=1, inplace=True)
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)     period
# 0                               el Raval          734.99 2017-01-01
# 1                         el Barri Gòtic          905.26 2017-01-01
# 2                         la Barceloneta          722.78 2017-01-01
# 3  Sant Pere, Santa Caterina i la Ribera          895.28 2017-01-01
# 4                          el Fort Pienc          871.08 2017-01-01

# %%
rent_m2_month_df = groupby_object.get_group('Euros/m2 month')
#rent_m2_month_df = rent_m2_month_df.set_index(['neighborhood_code', 'period'])
rent_m2_month_df.head()
# Out:
#      year  quarter  district_code district_name  neighborhood_code  \
# 292  2017        1              1  Ciutat Vella                  1
# 293  2017        1              1  Ciutat Vella                  2
# 294  2017        1              1  Ciutat Vella                  3
# 295  2017        1              1  Ciutat Vella                  4
# 296  2017        1              2      Eixample                  5
#
#                          neighborhood_name  type_mean_rent  price     period
# 292                               el Raval  Euros/m2 month  13.50 2017-01-01
# 293                         el Barri Gòtic  Euros/m2 month  14.14 2017-01-01
# 294                         la Barceloneta  Euros/m2 month  19.46 2017-01-01
# 295  Sant Pere, Santa Caterina i la Ribera  Euros/m2 month  15.01 2017-01-01
# 296                          el Fort Pienc  Euros/m2 month  12.77 2017-01-01

# %%
cleaned_rent_df = cleaned_rent_df.merge(rent_m2_month_df, how='left', on=['neighborhood_code', 'period'], suffixes=('', '_repeated'))
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)     period  \
# 0                               el Raval          734.99 2017-01-01
# 1                         el Barri Gòtic          905.26 2017-01-01
# 2                         la Barceloneta          722.78 2017-01-01
# 3  Sant Pere, Santa Caterina i la Ribera          895.28 2017-01-01
# 4                          el Fort Pienc          871.08 2017-01-01
#
#    year_repeated  quarter_repeated  district_code_repeated  \
# 0           2017                 1                       1
# 1           2017                 1                       1
# 2           2017                 1                       1
# 3           2017                 1                       1
# 4           2017                 1                       2
#
#   district_name_repeated             neighborhood_name_repeated  \
# 0           Ciutat Vella                               el Raval
# 1           Ciutat Vella                         el Barri Gòtic
# 2           Ciutat Vella                         la Barceloneta
# 3           Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 4               Eixample                          el Fort Pienc
#
#    type_mean_rent  price
# 0  Euros/m2 month  13.50
# 1  Euros/m2 month  14.14
# 2  Euros/m2 month  19.46
# 3  Euros/m2 month  15.01
# 4  Euros/m2 month  12.77

# %%
cleaned_rent_df = cleaned_rent_df.drop(list(cleaned_rent_df.filter(regex='_repeated')), axis=1)
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)     period  \
# 0                               el Raval          734.99 2017-01-01
# 1                         el Barri Gòtic          905.26 2017-01-01
# 2                         la Barceloneta          722.78 2017-01-01
# 3  Sant Pere, Santa Caterina i la Ribera          895.28 2017-01-01
# 4                          el Fort Pienc          871.08 2017-01-01
#
#    type_mean_rent  price
# 0  Euros/m2 month  13.50
# 1  Euros/m2 month  14.14
# 2  Euros/m2 month  19.46
# 3  Euros/m2 month  15.01
# 4  Euros/m2 month  12.77

# %%
cleaned_rent_df.drop('type_mean_rent', axis=1, inplace=True)
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)     period  price
# 0                               el Raval          734.99 2017-01-01  13.50
# 1                         el Barri Gòtic          905.26 2017-01-01  14.14
# 2                         la Barceloneta          722.78 2017-01-01  19.46
# 3  Sant Pere, Santa Caterina i la Ribera          895.28 2017-01-01  15.01
# 4                          el Fort Pienc          871.08 2017-01-01  12.77

# %%
cleaned_rent_df = cleaned_rent_df.rename(columns={'price':'price_m2_month(€)'})
cleaned_rent_df.head()
# Out:
#    year  quarter  district_code district_name  neighborhood_code  \
# 0  2017        1              1  Ciutat Vella                  1
# 1  2017        1              1  Ciutat Vella                  2
# 2  2017        1              1  Ciutat Vella                  3
# 3  2017        1              1  Ciutat Vella                  4
# 4  2017        1              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)     period  \
# 0                               el Raval          734.99 2017-01-01
# 1                         el Barri Gòtic          905.26 2017-01-01
# 2                         la Barceloneta          722.78 2017-01-01
# 3  Sant Pere, Santa Caterina i la Ribera          895.28 2017-01-01
# 4                          el Fort Pienc          871.08 2017-01-01
#
#    price_m2_month(€)
# 0              13.50
# 1              14.14
# 2              19.46
# 3              15.01
# 4              12.77

# %%
cleaned_rent_df = cleaned_rent_df.reindex(columns=['year', 'quarter', 'period', 'district_code', 'district_name', 'neighborhood_code', 'neighborhood_name', 'price_month(€)', 'price_m2_month(€)'])
cleaned_rent_df.head()
# Out:
#    year  quarter     period  district_code district_name  neighborhood_code  \
# 0  2017        1 2017-01-01              1  Ciutat Vella                  1
# 1  2017        1 2017-01-01              1  Ciutat Vella                  2
# 2  2017        1 2017-01-01              1  Ciutat Vella                  3
# 3  2017        1 2017-01-01              1  Ciutat Vella                  4
# 4  2017        1 2017-01-01              2      Eixample                  5
#
#                        neighborhood_name  price_month(€)  price_m2_month(€)
# 0                               el Raval          734.99              13.50
# 1                         el Barri Gòtic          905.26              14.14
# 2                         la Barceloneta          722.78              19.46
# 3  Sant Pere, Santa Caterina i la Ribera          895.28              15.01
# 4                          el Fort Pienc          871.08              12.77

# %%
cleaned_rent_df.to_csv('./data/cleaned/rent_prices.csv', index=False)
